# %%
# 1) How do you import the Seaborn package in Python?
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import a datafile 
df = pd.read_csv('https://raw.githubusercontent.com/juanklopper/TutorialData/main/heart_failure.csv')

# %%
# 2) How do you create a scatter plot in Seaborn for variables x and y in a DataFrame df?
sns.scatterplot(x='age', y='platelets', data=df)
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
# 3) How do you create a line plot in Seaborn for variables x and y in a DataFrame df?
sns.lineplot(x='age', y='platelets', data=df)
# Out:
# /Users/haleychokshi/miniconda3/envs/HealthDataScience/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/haleychokshi/miniconda3/envs/HealthDataScience/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='platelets'>

# %%
# 4) How do you create a histogram in Seaborn for a variable x in a DataFrame df?
sns.histplot(x='age', data=df)
# Out:
# /Users/haleychokshi/miniconda3/envs/HealthDataScience/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Count'>

# %%
# 5) How do you create a stacked histogram in Seaborn for variables x (age) and 'hue' y (anaemia) in a DataFrame df?
sns.displot(
    df,
    x='age',
    hue='anaemia',
    multiple='stack',
    bins = range(40, 110, 10)
).set(
    title='Stacked histogram of age and anaemia',
    xlabel='Age',
    ylabel='anaemia count'
);
# Out:
# /Users/haleychokshi/miniconda3/envs/HealthDataScience/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 6) How do you create a heatmap in Seaborn for a variable x = age and y = platelets in a DataFrame df?
sns.displot(
    df,
    x='age',
    y='platelets',
    cbar=True
).set(
    title='Age and Platelets',
    xlabel='Age ',
    ylabel='Platelet count'
);
# Out:
# /Users/haleychokshi/miniconda3/envs/HealthDataScience/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/haleychokshi/miniconda3/envs/HealthDataScience/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 7)How do you create a box plot in Seaborn for variables x and y in a DataFrame df?
sns.boxplot(
    df,
    x='age', 
    y='anaemia', 
).set(
    title='Boxplot of age and anaemia',
    xlabel='Age',
    ylabel='Anaemia'
);

# %%
# 8) How do you create a violin plot in Seaborn for variables x and y in a DataFrame df?
sns.violinplot(
    df,
    x='age', 
    y='anaemia', 
).set(
    title='Violin plot of age and anaemia',
    xlabel='Age',
    ylabel='Anaemia'
);

# %%
# 9) How do you create a bar plot in Seaborn for variables x and y in a DataFrame df?
sns.barplot(
    df,
    x='age', 
    y='anaemia', 
).set(
    title='Bar plot of age and anaemia',
    xlabel='Age',
    ylabel='Anaemia'
);

# %%
# 10) How do you add a title to a Seaborn plot assigned to the variable ax with the title 'My Title'?
ax = sns.scatterplot(x='age', y='platelets', data=df)
ax.set_title('My Title')
# Out:
# Text(0.5, 1.0, 'My Title')

# %%
# 11) How do you save a Seaborn plot ax to a file named 'output.png'?
ax = sns.scatterplot(x='age', y='platelets', data=df)
ax.set_title('My Title')
plt.savefig('output.png')

# %%
# 12) How do you set the x and y axis labels to 'X Label' and 'Y Label' respectively for a Seaborn plot ax?
ax = sns.scatterplot(x='age', y='platelets', data=df)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
# Out:
# Text(0, 0.5, 'Y Label')

# %%
# 13) How do you change the color palette of a Seaborn plot to 'Blues'?
sns.set_palette('Blues')
sns.scatterplot(x='age', y='platelets', data=df)
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
# 14) How do you display a Seaborn plot with a logarithmic scale on the y-axis?
sns.scatterplot(x='age', y='platelets', data=df)
plt.yscale('log')

# %%
# 15) How do you add a regression line to a scatter plot in Seaborn for variables x and y in a DataFrame df?
sns.regplot(x='age', y='platelets', data=df)
# Out:
# <Axes: xlabel='age', ylabel='platelets'>
