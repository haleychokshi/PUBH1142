# %%
#1
import pandas
import numpy

# %%
#2
Df = pandas.read_csv('https://raw.githubusercontent.com/juanklopper/TutorialData/main/PUBH1142Chap0801.csv')

# %%
#3
Df.head()
# Out:
#                 Name         DOB  Age               Vocation  Smoke  HR  sBP  \
# 0       Dylan Patton  1981-10-07   43         Energy manager      0  47  145
# 1      Sandra Howard  1993-01-27   53            Tax adviser      0  51  115
# 2  Samantha Williams  1973-12-21   33          IT consultant      0  54  120
# 3     Ashley Hensley  1981-12-01   43      Nurse, children's      0  54  103
# 4      Robert Wilson  1964-06-23   46  Clinical embryologist      0  61  138
#
#    CholesterolBefore  TAG  Survey  CholesterolAfter  Delta   Group
# 0                1.2  1.2       1               0.7    0.5  Active
# 1                1.2  0.6       3               1.0    0.2  Active
# 2                2.0  1.3       3               1.7    0.3  Active
# 3                2.1  1.6       4               2.1    0.0  Active
# 4                2.8  2.1       5               2.8    0.0  Active

# %%
#4 - the first number is the number of rows and the second number is the number of columns

Df.shape
# Out:
# (200, 13)

# %%
#5

Df.columns
# Out:
# Index(['Name', 'DOB', 'Age', 'Vocation', 'Smoke', 'HR', 'sBP',
#        'CholesterolBefore', 'TAG', 'Survey', 'CholesterolAfter', 'Delta',
#        'Group'],
#       dtype='object')

# %%
#6

Df.dtypes
# Out:
# Name                  object
# DOB                   object
# Age                    int64
# Vocation              object
# Smoke                  int64
# HR                     int64
# sBP                    int64
# CholesterolBefore    float64
# TAG                  float64
# Survey                 int64
# CholesterolAfter     float64
# Delta                float64
# Group                 object
# dtype: object

# %%
#7
AIsAge = (Df.Age == 5) | (Df.Age > 5)
AIsAge
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 195    True
# 196    True
# 197    True
# 198    True
# 199    True
# Name: Age, Length: 200, dtype: bool

# %%
#8

Df.iloc[0:200,[1, 2]]
# Out:
#             DOB  Age
# 0    1981-10-07   43
# 1    1993-01-27   53
# 2    1973-12-21   33
# 3    1981-12-01   43
# 4    1964-06-23   46
# ..          ...  ...
# 195  1936-11-25   66
# 196  1986-07-01   54
# 197  1959-01-30   61
# 198  1979-05-30   65
# 199  1972-07-27   66
#
# [200 rows x 2 columns]

# %%
#9

Df.rename(columns={'Age': "Alpha"}, inplace=True)
print (Df.columns)
# Out:
# Index(['Name', 'DOB', 'Alpha', 'Vocation', 'Smoke', 'HR', 'sBP',
#        'CholesterolBefore', 'TAG', 'Survey', 'CholesterolAfter', 'Delta',
#        'Group'],
#       dtype='object')

# %%
#10

Df.Group.replace({"nan": 999}, inplace=True)

# %%
#11

MissingData = Df.dropna()

# %%
#12

Df.fillna(method='ffill')
# Out:
# /var/folders/1s/5p4bbnfn2n90jr8myqywwm140000gn/T/ipykernel_1713/759561784.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Df.fillna(method='ffill')
#                   Name         DOB  Alpha                        Vocation  \
# 0         Dylan Patton  1981-10-07     43                  Energy manager
# 1        Sandra Howard  1993-01-27     53                     Tax adviser
# 2    Samantha Williams  1973-12-21     33                   IT consultant
# 3       Ashley Hensley  1981-12-01     43               Nurse, children's
# 4        Robert Wilson  1964-06-23     46           Clinical embryologist
# ..                 ...         ...    ...                             ...
# 195        John Curtis  1936-11-25     66          Sales professional, IT
# 196     Jessica Tanner  1986-07-01     54                       Paramedic
# ...

# %%
#13

AlphaData = Df['Alpha']
alpha = AlphaData.to_numpy
AlphaData.mean()
# Out:
# 53.07

# %%
#14
# create a new column C in DataFrame df that is the sum of columns Alpha and HR
Df['C'] = Df['Alpha'] + Df['HR']
print(Df.head())
# Out:
#                 Name         DOB  Alpha               Vocation  Smoke  HR  \
# 0       Dylan Patton  1981-10-07     43         Energy manager      0  47
# 1      Sandra Howard  1993-01-27     53            Tax adviser      0  51
# 2  Samantha Williams  1973-12-21     33          IT consultant      0  54
# 3     Ashley Hensley  1981-12-01     43      Nurse, children's      0  54
# 4      Robert Wilson  1964-06-23     46  Clinical embryologist      0  61
#
#    sBP  CholesterolBefore  TAG  Survey  CholesterolAfter  Delta   Group    C
# 0  145                1.2  1.2       1               0.7    0.5  Active   90
# 1  115                1.2  0.6       3               1.0    0.2  Active  104
# 2  120                2.0  1.3       3               1.7    0.3  Active   87
# 3  103                2.1  1.6       4               2.1    0.0  Active   97
# 4  138                2.8  2.1       5               2.8    0.0  Active  107

# %%
#15
# save the DataFrame df to a CSV file named output.csv
Df.to_csv('output.csv', index=False)
